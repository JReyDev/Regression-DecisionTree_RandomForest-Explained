# %%
import numpy as np
#Reduce variance is the goal, reduce distance


# Node class to represent nodes in the decision tree
class DecisionNode:
    def __init__(self, feature_index=0, threshold=0, value=None, left=None, right=None):
        self.feature_index = feature_index  # Index for the feature that is tested
        self.threshold = threshold  # Threshold value for feature split
        self.value = value  # Value of the node if it is a leaf in the tree
        self.left = left  # 'Left' subtree for values < threshold
        self.right = right  # 'Right' subtree for values >= threshold

# Decision tree class
class DecisionTreeRegressor:
    def __init__(self, min_samples_split=2, max_depth=2):
        # Initializing the tree as an empty node
        self.root = None

        # Stopping conditions for recursion
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth

    # Method to train the decision tree
    def fit(self, X, y, node=None, depth=0):
        if node is None:
            # Create a root node if it doesn't exist
            node = DecisionNode()
            self.root = node

        # If the number of samples is less than the minimum samples needed for a split
        # or if the max depth has been reached, make this node a leaf node and assign it the mean value of its group
        if (len(y) < self.min_samples_split) or (depth == self.max_depth):
            node.value = np.mean(y)
            return

        # Determine the best split
        feature_index, threshold = self._best_split(X, y)

        # If no valid split is possible, make this a leaf node as well
        if feature_index is None or threshold is None:
            node.value = np.mean(y)
            return

        # Assign the best feature index and threshold to this node
        node.feature_index = feature_index
        node.threshold = threshold

        # Create left and right child nodes
        node.left = DecisionNode()
        node.right = DecisionNode()

        # Create boolean mask for split
        left_indices = X[:, feature_index] < threshold
        right_indices = X[:, feature_index] >= threshold

        # Perform recursion
        self.fit(X[left_indices], y[left_indices], node.left, depth + 1)
        self.fit(X[right_indices], y[right_indices], node.right, depth + 1)



    def _best_split(self, X, y):
        best_feature_index = None
        best_threshold = None
        best_cost = np.inf

        # Iterate through all features
        for feature_index in range(X.shape[1]):
            # Check all possible thresholds
            possible_thresholds = np.unique(X[:, feature_index])
            print ('possible thresholds: ',possible_thresholds)
            
            # Evaluate all thresholds
            for threshold in possible_thresholds:
                cost = self._split_cost(X, y, feature_index, threshold)
                print ('current cost: ',cost)
                print ('current threshold: ',threshold)

                if cost < best_cost:
                    best_cost = cost
                    best_feature_index = feature_index
                    best_threshold = threshold
                    print('best cost: ', best_cost,'\n')

            print('best threshold: ',best_threshold)
            print('best feature index: ',best_feature_index)

        return best_feature_index, best_threshold



    # Method to calculate the cost of a split (total variance)
    def _split_cost(self, X, y, feature_index, threshold):
        left_indices = X[:, feature_index] < threshold
        print('left indice: ',left_indices)
        right_indices = X[:, feature_index] >= threshold
        print('right indices', right_indices)
        
        #print ('left indices: ', left_indices)

        # Calculate the cost as the sum of the squared deviation from the mean
        left_cost = self._cost(y[left_indices])
        print('left cost: ',left_cost)
        right_cost = self._cost(y[right_indices])
        print('right cost: ',right_cost)

        # Total cost is the sum of left and right cost
        cost = left_cost + right_cost
        print('final cost: ',cost)
        return cost

    # Calculate the variance of y values, sum of squared differences from the mean, no dividing to save computation power
    def _cost(self, y):
        if len(y) == 0:
            return 0
        return np.sum((y - np.mean(y)) ** 2)

    # Method to predict the target variable for a given feature vector
    def predict(self, X, node=None):
        if node is None:
            node = self.root

        # If we reach a leaf node, return the value of the node
        if node.value is not None:
            return node.value

        # Depending on the feature of X at the feature_index, decide whether to go left or right
        print ('is' ,X[node.feature_index] ,'less then: ',node.threshold)
        print ('predict feature index: ',node.feature_index, '\n')
        #print ('predict threshold: ', node.threshold)

        if X[node.feature_index] < node.threshold:
            return self.predict(X, node.left)
        else:
            return self.predict(X, node.right)

# %%
import numpy as np

# Trading volume (in '000s)
volume = np.array([1000, 1200, 1500, 2000, 1800, 2100, 1900, 1600])

# Opening price (in $)
open_price = np.array([50, 52, 51, 53, 54, 56, 55, 57])

# Closing price (in $)
close_price = np.array([51.49671415, 53.0617357 , 53.14768854, 56.52302986, 55.56584663, 57.86586304, 58.47921282, 59.36743473])

# Features
X = np.column_stack([volume, open_price])
# Target
y = close_price

# %%
X.shape
# Out:
# (8, 2)

# %%
# Initialize the DecisionTreeRegressor object
tree = DecisionTreeRegressor(min_samples_split=2, max_depth=5)

# Fit the model to the data
tree.fit(X, y)

# Predict the closing price for a new data point
new_data = np.array([3000, 70])  # New data point: volume = 3000 ('000s), opening price = $70
predicted_close_price = tree.predict(new_data)
print(predicted_close_price)
# Out:
# possible thresholds:  [1000 1200 1500 1600 1800 1900 2000 2100]
# left indice:  [False False False False False False False False]
# right indices [ True  True  True  True  True  True  True  True]
# left cost:  0
# right cost:  57.701714682809246
# final cost:  57.701714682809246
# current cost:  57.701714682809246
# current threshold:  1000
# best cost:  57.701714682809246
#
# left indice:  [ True False False False False False False False]
# right indices [False  True  True  True  True  True  True  True]
# left cost:  0.0
# right cost:  37.62106172995922
# final cost:  37.62106172995922
# current cost:  37.62106172995922
# current threshold:  1200
# best cost:  37.62106172995922
#
# left indice:  [ True  True False False False False False False]
# right indices [False False  True  True  True  True  True  True]
# left cost:  1.224646225982197
# right cost:  25.483062884268822
# final cost:  26.70770911025102
# current cost:  26.70770911025102
# current threshold:  1500
# best cost:  26.70770911025102
#
# left indice:  [ True  True  True False False False False False]
# right indices [False False False  True  True  True  True  True]
# left cost:  1.7274655930347713
# right cost:  9.257279060436343
# final cost:  10.984744653471115
# current cost:  10.984744653471115
# current threshold:  1600
# best cost:  10.984744653471115
#
# left indice:  [ True  True  True False False False False  True]
# right indices [False False False  True  True  True  True False]
# left cost:  36.39443053812557
# right cost:  5.175007113506733
# final cost:  41.5694376516323
# current cost:  41.5694376516323
# current threshold:  1800
# left indice:  [ True  True  True False  True False False  True]
# right indices [False False False  True False  True  True False]
# left cost:  37.74113869446656
# right cost:  2.0020168916431063
# final cost:  39.743155586109665
# current cost:  39.743155586109665
# current threshold:  1900
# left indice:  [ True  True  True False  True False  True  True]
# right indices [False False False  True False  True False False]
# left cost:  50.75197189354613
# right cost:  0.9016004746544556
# final cost:  51.653572368200585
# current cost:  51.653572368200585
# current threshold:  2000
# left indice:  [ True  True  True  True  True False  True  True]
# right indices [False False False False False  True False False]
# left cost:  52.283236834240896
# right cost:  0.0
# final cost:  52.283236834240896
# current cost:  52.283236834240896
# current threshold:  2100
# best threshold:  1600
# best feature index:  0
# possible thresholds:  [50 51 52 53 54 55 56 57]
# left indice:  [False False False False False False False False]
# right indices [ True  True  True  True  True  True  True  True]
# left cost:  0
# right cost:  57.701714682809246
# final cost:  57.701714682809246
# current cost:  57.701714682809246
# current threshold:  50
# left indice:  [ True False False False False False False False]
# right indices [False  True  True  True  True  True  True  True]
# left cost:  0.0
# right cost:  37.62106172995922
# final cost:  37.62106172995922
# current cost:  37.62106172995922
# current threshold:  51
# left indice:  [ True False  True False False False False False]
# right indices [False  True False  True  True  True  True  True]
# left cost:  1.3628582182179274
# right cost:  26.12134370259654
# final cost:  27.484201920814467
# current cost:  27.484201920814467
# current threshold:  52
# left indice:  [ True  True  True False False False False False]
# right indices [False False False  True  True  True  True  True]
# left cost:  1.7274655930347713
# right cost:  9.257279060436343
# final cost:  10.984744653471115
# current cost:  10.984744653471115
# current threshold:  53
# left indice:  [ True  True  True  True False False False False]
# right indices [False False False False  True  True  True  True]
# left cost:  13.454933171061647
# right cost:  7.912425944901377
# final cost:  21.367359115963026
# current cost:  21.367359115963026
# current threshold:  54
# left indice:  [ True  True  True  True  True False False False]
# right indices [False False False False False  True  True  True]
# left cost:  16.682366331561745
# right cost:  1.1399512180798488
# final cost:  17.822317549641593
# current cost:  17.822317549641593
# current threshold:  55
# left indice:  [ True  True  True  True  True False  True False]
# right indices [False False False False False  True False  True]
# left cost:  33.7092805263905
# right cost:  1.127358770104726
# final cost:  34.83663929649523
# current cost:  34.83663929649523
# current threshold:  56
# left indice:  [ True  True  True  True  True  True  True False]
# right indices [False False False False False False False  True]
# left cost:  42.23314646298874
# right cost:  0.0
# final cost:  42.23314646298874
# current cost:  42.23314646298874
# current threshold:  57
# best threshold:  1600
# best feature index:  0
# possible thresholds:  [1000 1200 1500]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.7274655930347713
# final cost:  1.7274655930347713
# current cost:  1.7274655930347713
# current threshold:  1000
# best cost:  1.7274655930347713
#
# left indice:  [ True False False]
# right indices [False  True  True]
# left cost:  0.0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  1200
# best cost:  0.003693945352032574
#
# left indice:  [ True  True False]
# right indices [False False  True]
# left cost:  1.224646225982197
# right cost:  0.0
# final cost:  1.224646225982197
# current cost:  1.224646225982197
# current threshold:  1500
# best threshold:  1200
# best feature index:  0
# possible thresholds:  [50 51 52]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.7274655930347713
# final cost:  1.7274655930347713
# current cost:  1.7274655930347713
# current threshold:  50
# left indice:  [ True False False]
# right indices [False  True  True]
# left cost:  0.0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  51
# left indice:  [ True False  True]
# right indices [False  True False]
# left cost:  1.3628582182179274
# right cost:  0.0
# final cost:  1.3628582182179274
# current cost:  1.3628582182179274
# current threshold:  52
# best threshold:  1200
# best feature index:  0
# possible thresholds:  [1200 1500]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  1200
# best cost:  0.003693945352032574
#
# left indice:  [ True False]
# right indices [False  True]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  1500
# best cost:  0.0
#
# best threshold:  1500
# best feature index:  0
# possible thresholds:  [51 52]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  51
# left indice:  [False  True]
# right indices [ True False]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  52
# best threshold:  1500
# best feature index:  0
# possible thresholds:  [1600 1800 1900 2000 2100]
# left indice:  [False False False False False]
# right indices [ True  True  True  True  True]
# left cost:  0
# right cost:  9.257279060436343
# final cost:  9.257279060436343
# current cost:  9.257279060436343
# current threshold:  1600
# best cost:  9.257279060436343
#
# left indice:  [False False False False  True]
# right indices [ True  True  True  True False]
# left cost:  0.0
# right cost:  5.175007113506733
# final cost:  5.175007113506733
# current cost:  5.175007113506733
# current threshold:  1800
# best cost:  5.175007113506733
#
# left indice:  [False  True False False  True]
# right indices [ True False  True  True False]
# left cost:  7.226036041030792
# right cost:  2.0020168916431063
# final cost:  9.228052932673897
# current cost:  9.228052932673897
# current threshold:  1900
# left indice:  [False  True False  True  True]
# right indices [ True False  True False False]
# left cost:  7.909570933500245
# right cost:  0.9016004746544556
# final cost:  8.811171408154701
# current cost:  8.811171408154701
# current threshold:  2000
# left indice:  [ True  True False  True  True]
# right indices [False False  True False False]
# left cost:  9.140550843442007
# right cost:  0.0
# final cost:  9.140550843442007
# current cost:  9.140550843442007
# current threshold:  2100
# best threshold:  1800
# best feature index:  0
# possible thresholds:  [53 54 55 56 57]
# left indice:  [False False False False False]
# right indices [ True  True  True  True  True]
# left cost:  0
# right cost:  9.257279060436343
# final cost:  9.257279060436343
# current cost:  9.257279060436343
# current threshold:  53
# left indice:  [ True False False False False]
# right indices [False  True  True  True  True]
# left cost:  0.0
# right cost:  7.912425944901377
# final cost:  7.912425944901377
# current cost:  7.912425944901377
# current threshold:  54
# left indice:  [ True  True False False False]
# right indices [False False  True  True  True]
# left cost:  0.4580998678966148
# right cost:  1.1399512180798488
# final cost:  1.5980510859764636
# current cost:  1.5980510859764636
# current threshold:  55
# best cost:  1.5980510859764636
#
# left indice:  [ True  True False  True False]
# right indices [False False  True False  True]
# left cost:  4.410184688607565
# right cost:  1.127358770104726
# final cost:  5.537543458712291
# current cost:  5.537543458712291
# current threshold:  56
# left indice:  [ True  True  True  True False]
# right indices [False False False False  True]
# left cost:  5.175007113506733
# right cost:  0.0
# final cost:  5.175007113506733
# current cost:  5.175007113506733
# current threshold:  57
# best threshold:  55
# best feature index:  1
# possible thresholds:  [1800 2000]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.4580998678966148
# final cost:  0.4580998678966148
# current cost:  0.4580998678966148
# current threshold:  1800
# best cost:  0.4580998678966148
#
# left indice:  [False  True]
# right indices [ True False]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  2000
# best cost:  0.0
#
# best threshold:  2000
# best feature index:  0
# possible thresholds:  [53 54]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.4580998678966148
# final cost:  0.4580998678966148
# current cost:  0.4580998678966148
# current threshold:  53
# left indice:  [ True False]
# right indices [False  True]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  54
# best threshold:  2000
# best feature index:  0
# possible thresholds:  [1600 1900 2100]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.1399512180798488
# final cost:  1.1399512180798488
# current cost:  1.1399512180798488
# current threshold:  1600
# best cost:  1.1399512180798488
#
# left indice:  [False False  True]
# right indices [ True  True False]
# left cost:  0.0
# right cost:  0.18809897631302425
# final cost:  0.18809897631302425
# current cost:  0.18809897631302425
# current threshold:  1900
# best cost:  0.18809897631302425
#
# left indice:  [False  True  True]
# right indices [ True False False]
# left cost:  0.3944690807020228
# right cost:  0.0
# final cost:  0.3944690807020228
# current cost:  0.3944690807020228
# current threshold:  2100
# best threshold:  1900
# best feature index:  0
# possible thresholds:  [55 56 57]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.1399512180798488
# final cost:  1.1399512180798488
# current cost:  1.1399512180798488
# current threshold:  55
# left indice:  [False  True False]
# right indices [ True False  True]
# left cost:  0.0
# right cost:  1.127358770104726
# final cost:  1.127358770104726
# current cost:  1.127358770104726
# current threshold:  56
# left indice:  [ True  True False]
# right indices [False False  True]
# left cost:  0.18809897631302425
# right cost:  0.0
# final cost:  0.18809897631302425
# current cost:  0.18809897631302425
# current threshold:  57
# best threshold:  1900
# best feature index:  0
# possible thresholds:  [1900 2100]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.18809897631302425
# final cost:  0.18809897631302425
# current cost:  0.18809897631302425
# current threshold:  1900
# best cost:  0.18809897631302425
#
# left indice:  [False  True]
# right indices [ True False]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  2100
# best cost:  0.0
#
# best threshold:  2100
# best feature index:  0
# possible thresholds:  [55 56]
# left indice:  [False False]
# right indices [ True  True]
# left cost:  0
# right cost:  0.18809897631302425
# final cost:  0.18809897631302425
# current cost:  0.18809897631302425
# current threshold:  55
# left indice:  [False  True]
# right indices [ True False]
# left cost:  0.0
# right cost:  0.0
# final cost:  0.0
# current cost:  0.0
# current threshold:  56
# best threshold:  2100
# best feature index:  0
# is 3000 less then:  1600
# predict feature index:  0
#
# is 70 less then:  55
# predict feature index:  1
#
# is 3000 less then:  1900
# predict feature index:  0
#
# is 3000 less then:  2100
# predict feature index:  0
#
# 57.86586304

# %%
def predict(self, X, node=None):
    if node is None:
        node = self.root

    # If we reach a leaf node, return the value of the node
    if node.value is not None:
        return node.value

    # Depending on the feature of X at the feature_index, decide whether to go left or right
    print ('is' ,X[node.feature_index] ,'less then: ',node.threshold)
    print ('predict feature index: ',node.feature_index)
    #print ('predict threshold: ', node.threshold)

    if X[node.feature_index] < node.threshold:
        return self.predict(X, node.left)
    else:
        return self.predict(X, node.right)

# %%
np.sum((y[1:] - np.mean(y[1:])) ** 2)
# Out:
# 37.62106172995922

# %%
(y - np.mean(y)) ** 2
# Out:
# array([1.75705713e+01, 6.89957907e+00, 6.45542146e+00, 6.96539093e-01,
#        1.50293020e-02, 4.74116812e+00, 7.78840912e+00, 1.35349972e+01])

# %%
np.mean(y[1:])
# Out:
# 56.28725876

# %%
y[1:]
# Out:
# array([53.0617357 , 53.14768854, 56.52302986, 55.56584663, 57.86586304,
#        58.47921282, 59.36743473])

# %%
np.sum([1.75705713e+01, 6.89957907e+00, 6.45542146e+00, 6.96539093e-01,
       1.50293020e-02, 4.74116812e+00, 7.78840912e+00, 1.35349972e+01])
# Out:
# 57.701714665

# %%
# Create a regression tree instance
tree = DecisionTreeRegressor()

# Fit the tree to your data
tree.fit(X, y)

# Access the root node
root = tree.root

# Print the feature and threshold chosen for the root node
print(f"Root node splits on feature {root.feature_index} with threshold {root.threshold}")
# Out:
# possible thresholds:  [1000 1200 1500 1600 1800 1900 2000 2100]
# left indice:  [False False False False False False False False]
# right indices [ True  True  True  True  True  True  True  True]
# left cost:  0
# right cost:  57.701714682809246
# final cost:  57.701714682809246
# current cost:  57.701714682809246
# current threshold:  1000
# best cost:  57.701714682809246
#
# left indice:  [ True False False False False False False False]
# right indices [False  True  True  True  True  True  True  True]
# left cost:  0.0
# right cost:  37.62106172995922
# final cost:  37.62106172995922
# current cost:  37.62106172995922
# current threshold:  1200
# best cost:  37.62106172995922
#
# left indice:  [ True  True False False False False False False]
# right indices [False False  True  True  True  True  True  True]
# left cost:  1.224646225982197
# right cost:  25.483062884268822
# final cost:  26.70770911025102
# current cost:  26.70770911025102
# current threshold:  1500
# best cost:  26.70770911025102
#
# left indice:  [ True  True  True False False False False False]
# right indices [False False False  True  True  True  True  True]
# left cost:  1.7274655930347713
# right cost:  9.257279060436343
# final cost:  10.984744653471115
# current cost:  10.984744653471115
# current threshold:  1600
# best cost:  10.984744653471115
#
# left indice:  [ True  True  True False False False False  True]
# right indices [False False False  True  True  True  True False]
# left cost:  36.39443053812557
# right cost:  5.175007113506733
# final cost:  41.5694376516323
# current cost:  41.5694376516323
# current threshold:  1800
# left indice:  [ True  True  True False  True False False  True]
# right indices [False False False  True False  True  True False]
# left cost:  37.74113869446656
# right cost:  2.0020168916431063
# final cost:  39.743155586109665
# current cost:  39.743155586109665
# current threshold:  1900
# left indice:  [ True  True  True False  True False  True  True]
# right indices [False False False  True False  True False False]
# left cost:  50.75197189354613
# right cost:  0.9016004746544556
# final cost:  51.653572368200585
# current cost:  51.653572368200585
# current threshold:  2000
# left indice:  [ True  True  True  True  True False  True  True]
# right indices [False False False False False  True False False]
# left cost:  52.283236834240896
# right cost:  0.0
# final cost:  52.283236834240896
# current cost:  52.283236834240896
# current threshold:  2100
# best threshold:  1600
# best feature index:  0
# possible thresholds:  [50 51 52 53 54 55 56 57]
# left indice:  [False False False False False False False False]
# right indices [ True  True  True  True  True  True  True  True]
# left cost:  0
# right cost:  57.701714682809246
# final cost:  57.701714682809246
# current cost:  57.701714682809246
# current threshold:  50
# left indice:  [ True False False False False False False False]
# right indices [False  True  True  True  True  True  True  True]
# left cost:  0.0
# right cost:  37.62106172995922
# final cost:  37.62106172995922
# current cost:  37.62106172995922
# current threshold:  51
# left indice:  [ True False  True False False False False False]
# right indices [False  True False  True  True  True  True  True]
# left cost:  1.3628582182179274
# right cost:  26.12134370259654
# final cost:  27.484201920814467
# current cost:  27.484201920814467
# current threshold:  52
# left indice:  [ True  True  True False False False False False]
# right indices [False False False  True  True  True  True  True]
# left cost:  1.7274655930347713
# right cost:  9.257279060436343
# final cost:  10.984744653471115
# current cost:  10.984744653471115
# current threshold:  53
# left indice:  [ True  True  True  True False False False False]
# right indices [False False False False  True  True  True  True]
# left cost:  13.454933171061647
# right cost:  7.912425944901377
# final cost:  21.367359115963026
# current cost:  21.367359115963026
# current threshold:  54
# left indice:  [ True  True  True  True  True False False False]
# right indices [False False False False False  True  True  True]
# left cost:  16.682366331561745
# right cost:  1.1399512180798488
# final cost:  17.822317549641593
# current cost:  17.822317549641593
# current threshold:  55
# left indice:  [ True  True  True  True  True False  True False]
# right indices [False False False False False  True False  True]
# left cost:  33.7092805263905
# right cost:  1.127358770104726
# final cost:  34.83663929649523
# current cost:  34.83663929649523
# current threshold:  56
# left indice:  [ True  True  True  True  True  True  True False]
# right indices [False False False False False False False  True]
# left cost:  42.23314646298874
# right cost:  0.0
# final cost:  42.23314646298874
# current cost:  42.23314646298874
# current threshold:  57
# best threshold:  1600
# best feature index:  0
# possible thresholds:  [1000 1200 1500]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.7274655930347713
# final cost:  1.7274655930347713
# current cost:  1.7274655930347713
# current threshold:  1000
# best cost:  1.7274655930347713
#
# left indice:  [ True False False]
# right indices [False  True  True]
# left cost:  0.0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  1200
# best cost:  0.003693945352032574
#
# left indice:  [ True  True False]
# right indices [False False  True]
# left cost:  1.224646225982197
# right cost:  0.0
# final cost:  1.224646225982197
# current cost:  1.224646225982197
# current threshold:  1500
# best threshold:  1200
# best feature index:  0
# possible thresholds:  [50 51 52]
# left indice:  [False False False]
# right indices [ True  True  True]
# left cost:  0
# right cost:  1.7274655930347713
# final cost:  1.7274655930347713
# current cost:  1.7274655930347713
# current threshold:  50
# left indice:  [ True False False]
# right indices [False  True  True]
# left cost:  0.0
# right cost:  0.003693945352032574
# final cost:  0.003693945352032574
# current cost:  0.003693945352032574
# current threshold:  51
# left indice:  [ True False  True]
# right indices [False  True False]
# left cost:  1.3628582182179274
# right cost:  0.0
# final cost:  1.3628582182179274
# current cost:  1.3628582182179274
# current threshold:  52
# best threshold:  1200
# best feature index:  0
# possible thresholds:  [1600 1800 1900 2000 2100]
# left indice:  [False False False False False]
# right indices [ True  True  True  True  True]
# left cost:  0
# right cost:  9.257279060436343
# final cost:  9.257279060436343
# current cost:  9.257279060436343
# current threshold:  1600
# best cost:  9.257279060436343
#
# left indice:  [False False False False  True]
# right indices [ True  True  True  True False]
# left cost:  0.0
# right cost:  5.175007113506733
# final cost:  5.175007113506733
# current cost:  5.175007113506733
# current threshold:  1800
# best cost:  5.175007113506733
#
# left indice:  [False  True False False  True]
# right indices [ True False  True  True False]
# left cost:  7.226036041030792
# right cost:  2.0020168916431063
# final cost:  9.228052932673897
# current cost:  9.228052932673897
# current threshold:  1900
# left indice:  [False  True False  True  True]
# right indices [ True False  True False False]
# left cost:  7.909570933500245
# right cost:  0.9016004746544556
# final cost:  8.811171408154701
# current cost:  8.811171408154701
# current threshold:  2000
# left indice:  [ True  True False  True  True]
# right indices [False False  True False False]
# left cost:  9.140550843442007
# right cost:  0.0
# final cost:  9.140550843442007
# current cost:  9.140550843442007
# current threshold:  2100
# best threshold:  1800
# best feature index:  0
# possible thresholds:  [53 54 55 56 57]
# left indice:  [False False False False False]
# right indices [ True  True  True  True  True]
# left cost:  0
# right cost:  9.257279060436343
# final cost:  9.257279060436343
# current cost:  9.257279060436343
# current threshold:  53
# left indice:  [ True False False False False]
# right indices [False  True  True  True  True]
# left cost:  0.0
# right cost:  7.912425944901377
# final cost:  7.912425944901377
# current cost:  7.912425944901377
# current threshold:  54
# left indice:  [ True  True False False False]
# right indices [False False  True  True  True]
# left cost:  0.4580998678966148
# right cost:  1.1399512180798488
# final cost:  1.5980510859764636
# current cost:  1.5980510859764636
# current threshold:  55
# best cost:  1.5980510859764636
#
# left indice:  [ True  True False  True False]
# right indices [False False  True False  True]
# left cost:  4.410184688607565
# right cost:  1.127358770104726
# final cost:  5.537543458712291
# current cost:  5.537543458712291
# current threshold:  56
# left indice:  [ True  True  True  True False]
# right indices [False False False False  True]
# left cost:  5.175007113506733
# right cost:  0.0
# final cost:  5.175007113506733
# current cost:  5.175007113506733
# current threshold:  57
# best threshold:  55
# best feature index:  1
# Root node splits on feature 0 with threshold 1600
